# %% [markdown]
# # Week 12 Review Assignmnet
#
# For the questions below, we're going to refer exclusively to an HHCAPS survey data set that is available in `/data/hhcaps.csv`.  Use whatever commands you want to calculate the information required to get to the answer.  Then, enter your answer in the answers cell as usual.
#
# **NOTE: Enter your answers as string values (inside quotation marks "") even if the answer is actually numeric.**
#
# ---
# ---

# %%
# %matplotlib inline
import pandas as pd

hhcaps = pd.read_csv('/data/hhcaps.csv')

# %% [markdown]
# ## #01 -
#
# How many columns does this file contain?

# %%
hhcaps.shape
# Out:
# (12000, 39)

# %%
hhcaps.head()
# Out:
#   State  CMS Certification Number (CCN)*  \
# 0    AL                            17000
# 1    AL                            17008
# 2    AL                            17009
# 3    AL                            17013
# 4    AL                            17014
#
#                                        Provider Name  \
# 0  BUREAU OF HOME & COMMUNITY SERVICES           ...
# 1  JEFFERSON COUNTY HOME CARE                    ...
# 2  ALACARE HOME HEALTH & HOSPICE                 ...
# 3  GENTIVA HEALTH SERVICES                       ...
# 4  AMEDISYS HOME HEALTH                          ...
#
#                                              Address                  City  \
# 0  201 MONROE STREET, THE RSA TOWER,  SUITE 1200 ...  MONTGOMERY
# 1  2201 ARLINGTON AVENUE                         ...  BESSEMER
# 2  2970 LORNA ROAD                               ...  BIRMINGHAM
# 3  1239 RUCKER BLVD                              ...  ENTERPRISE
# 4  68278 MAIN STREET                             ...  BLOUNTSVILLE
#
#      Zip       Phone       Type of Ownership  Offers Nursing Care Services  \
# 0  36104  3342065341  Official Health Agency                          True
# 1  35020  2059169500  Official Health Agency                          True
# 2  35216  2058242680                   Local                          True
# 3  36330  3343470234  Official Health Agency                          True
# 4  35031  2054294919                   Local                          True
#
#    Offers Physical Therapy Services  ...  \
# 0                              True  ...
# 1                              True  ...
# 2                              True  ...
# 3                              True  ...
# 4                              True  ...
#
#    Star Rating for how patients rated overall care from agency  \
# 0                                                NaN
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Footnote for Star Rating for overall care from agency  \
# 0   No survey results are available for this period.
# 1  Fewer than 100 patients completed the survey. ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0                                      Not Available
# 1                                                 91
# 2                                                 88
# 3                                                 91
# 4                                                 88
#
#    Footnote for percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0   No survey results are available for this period.
# 1  Fewer than 100 patients completed the survey. ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0                                      Not Available
# 1                                                 77
# 2                                                 81
# 3                                                 91
# 4                                                 79
#
#    Footnote for percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0   No survey results are available for this period.
# 1  Fewer than 100 patients completed the survey. ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Number of completed Surveys  \
# 0               Not Available
# 1                          55
# 2                         327
# 3                         252
# 4                         205
#
#             Footnote for number of completed surveys  Response rate  \
# 0   No survey results are available for this period.  Not Available
# 1  Fewer than 100 patients completed the survey. ...             23
# 2                                                NaN             32
# 3                                                NaN             34
# 4                                                NaN             34
#
#                           Footnote for response rate
# 0   No survey results are available for this period.
# 1  Fewer than 100 patients completed the survey. ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 39 columns]

# %%
answers={}
answers['56.1'] = "39"

# %% [markdown]
# ## #02 -
#
# How many different values for State are there in this file?

# %%
hhcaps.State.nunique()
# Out:
# 55

# %%
answers['56.2'] = "55"

# %% [markdown]
# ## #03 -
#
# Which of those State values has the highest frequency of occurence?

# %%
hhcaps.mode()
# Out:
#       State  CMS Certification Number (CCN)*  \
# 0        TX                            17000
# 1       NaN                            17008
# 2       NaN                            17009
# 3       NaN                            17013
# 4       NaN                            17014
# ...     ...                              ...
# 11995   NaN                           747978
# 11996   NaN                           747979
# 11997   NaN                           747980
# 11998   NaN                           747981
# 11999   NaN                           747982
#
#                                            Provider Name  \
# 0      KINDRED AT HOME                               ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#                                                  Address  \
# 0      4340 GLENDALE-MILFORD ROAD, SUITE 100         ...
# 1      742 WAYCROSS ROAD                             ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#                        City      Zip         Phone Type of Ownership  \
# 0      HOUSTON               77036.0  9.108153e+09             Local
# 1                       NaN      NaN           NaN               NaN
# 2                       NaN      NaN           NaN               NaN
# 3                       NaN      NaN           NaN               NaN
# 4                       NaN      NaN           NaN               NaN
# ...                     ...      ...           ...               ...
# 11995                   NaN      NaN           NaN               NaN
# 11996                   NaN      NaN           NaN               NaN
# 11997                   NaN      NaN           NaN               NaN
# 11998                   NaN      NaN           NaN               NaN
# 11999                   NaN      NaN           NaN               NaN
#
#       Offers Nursing Care Services Offers Physical Therapy Services  ...  \
# 0                             True                             True  ...
# 1                              NaN                              NaN  ...
# 2                              NaN                              NaN  ...
# 3                              NaN                              NaN  ...
# 4                              NaN                              NaN  ...
# ...                            ...                              ...  ...
# 11995                          NaN                              NaN  ...
# 11996                          NaN                              NaN  ...
# 11997                          NaN                              NaN  ...
# 11998                          NaN                              NaN  ...
# 11999                          NaN                              NaN  ...
#
#       Star Rating for how patients rated overall care from agency  \
# 0                                                    3.0
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#       Footnote for Star Rating for overall care from agency  \
# 0       No survey results are available for this period.
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#       Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0                                          Not Available
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#       Footnote for percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0       No survey results are available for this period.
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#       Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0                                          Not Available
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#        Footnote for percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0       No survey results are available for this period.
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11995                                                NaN
# 11996                                                NaN
# 11997                                                NaN
# 11998                                                NaN
# 11999                                                NaN
#
#       Number of completed Surveys  \
# 0                   Not Available
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 11995                         NaN
# 11996                         NaN
# 11997                         NaN
# 11998                         NaN
# 11999                         NaN
#
#                Footnote for number of completed surveys  Response rate  \
# 0      No survey results are available for this period.  Not Available
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 11995                                               NaN            NaN
# 11996                                               NaN            NaN
# 11997                                               NaN            NaN
# 11998                                               NaN            NaN
# 11999                                               NaN            NaN
#
#                              Footnote for response rate
# 0      No survey results are available for this period.
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 11995                                               NaN
# 11996                                               NaN
# 11997                                               NaN
# 11998                                               NaN
# 11999                                               NaN
#
# [12000 rows x 39 columns]

# %%
answers['56.3'] = "TX"

# %% [markdown]
# ## #04 -
#
# Which of those State values has the best average performance on the `Star Rating for health team communicated well with them` score?

# %%
hhcaps.groupby(['State'])['Star Rating for health team communicated well with them'].mean()
# Out:
# State
# AK    3.500000
# AL    4.507692
# AR    4.384615
# AZ    3.277108
# CA    3.104508
# CO    3.770833
# CT    3.550725
# DC    2.000000
# DE    3.846154
# FL    3.645228
# GA    3.917526
# GU         NaN
# HI    3.818182
# IA    4.204082
# ID    3.972222
# IL    3.667820
# IN    4.030075
# KS    4.166667
# KY    4.484536
# LA    4.487805
# MA    3.817308
# MD    3.695652
# ME    4.650000
# MI    3.716279
# MN    3.544554
# MO    4.300885
# MP         NaN
# MS    4.636364
# MT    4.333333
# NC    4.138158
# ND    4.250000
# NE    4.250000
# NH    4.136364
# NJ    3.833333
# NM    3.714286
# NV    3.000000
# NY    3.378641
# OH    3.666667
# OK    4.128655
# OR    3.409091
# PA    4.148325
# PR    2.846154
# RI    3.947368
# SC    4.333333
# SD    4.166667
# TN    4.372881
# TX    3.811648
# UT    3.603774
# VA    3.865772
# VI    4.000000
# VT    4.272727
# WA    3.642857
# WI    4.101449
# WV    4.647059
# WY    3.833333
# Name: Star Rating for health team communicated well with them, dtype: float64

# %%
answers['56.4'] = "ME"

# %% [markdown]
# ## #05 -
#
# What was the average score on `Star Rating for how patients rated overall care from agency` for providers listed as having a `Type of Ownership` of `Hospital Based Program`
#
# **NOTE: Enter your answer with two decimal precision: 0.00**

# %%
ownership_filter = hhcaps['Type of Ownership'] == 'Hospital Based Program'

# %%
hhcaps_filtered = hhcaps[ownership_filter]

# %%
hhcaps_final = hhcaps_filtered.groupby(['Provider Name'])['Star Rating for how patients rated overall care from agency'].mean()

# %%
hhcaps_final
# Out:
# Provider Name
# ABINGTON MEMORIAL HOSPITAL  HOME CARE                 4.0
# ACMC FAMILY HOME HEALTH                               5.0
# ADENA HOME HEALTH                                     3.0
# ADVENTIST HEALTH CARE AT HOME                         3.0
# ADVENTIST HEALTH HOME CARE SERVICES                   3.0
#                                                      ...
# YADKIN VALLEY HOME HEALT                              4.0
# YOAKUM COUNTY HOSPITAL HOME HEALTH                    NaN
# YORK GENERAL HOSP HOME HEALTH                         3.0
# YORK HOSPITAL HOME CARE                               4.0
# YUMA DISTRICT HOSPITAL HOME HEALTH CARE               NaN
# Name: Star Rating for how patients rated overall care from agency, Length: 847, dtype: float64

# %%
hhcaps_final.mean()
# Out:
# 3.697158273381295

# %%
answers['56.5'] = "3.69"

# %% [markdown]
# ---
#
# Checking Your Work
# ---
#
# After completing your work above and running each cell, you can check your answers by running the code below.
#
# The easiest way to do this is to use the `Kernel` -> `Restart Kernel and Run All Cells` menu option. This option restarts Python and runs every cell from top to bottom until it encounters an exception of some kind.  It will stop after running the cell below and outputing a summary of how many answers you have correct or incorrect.

# %%
import getpass
import boto3
import json

test = {
    "user": getpass.getuser(),
    "week": "week12",
    "answers": answers
}

client = boto3.client('lambda')

response = client.invoke(
    FunctionName="hds5210-2021",
    InvocationType="RequestResponse",
    Payload=json.dumps(test))

result = json.loads(response['Payload'].read().decode('utf-8'))
print(response)

print('{0:>5}{1:>20}{2:>10}'.format('Q#','Yours','Correct?'))
for row in result.get('results'):
    print('{0:>5}{1:>20}{2:>10}'.format(str(row[0]),str(row[1]),str(row[2])))
# Out:
# {'ResponseMetadata': {'RequestId': '4de34ef8-d3ed-4c18-b959-927b97b50640', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 19 Apr 2021 16:33:53 GMT', 'content-type': 'application/json', 'content-length': '213', 'connection': 'keep-alive', 'x-amzn-requestid': '4de34ef8-d3ed-4c18-b959-927b97b50640', 'x-amzn-remapped-content-length': '0', 'x-amz-executed-version': '$LATEST', 'x-amzn-trace-id': 'root=1-607db0f1-1e02f2a97944303e560480c4;sampled=0'}, 'RetryAttempts': 0}, 'StatusCode': 200, 'ExecutedVersion': '$LATEST', 'Payload': <botocore.response.StreamingBody object at 0x7f94ce1ab9e8>}
#    Q#               Yours  Correct?
#  56.1                  39        OK
#  56.2                  55        OK
#  56.3                  TX        OK
#  56.4                  ME        OK
#  56.5                3.69        OK

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  The first line of code below will **pull** down my comments into your local folders.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-cef8011cb395> in <module>
# ----> 1 assert False, "DO NOT REMOVE THIS LINE"
#
# AssertionError: DO NOT REMOVE THIS LINE

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week12_assignment_1.ipynb
# git commit -a -m "Submitting the week 12 review"
# git push
# Out:
# Already up to date.
# [main d20534e] Submitting the week 12 review
#  2 files changed, 1426 insertions(+), 2 deletions(-)
#  create mode 100644 week12/week12_assignment_1.ipynb
# To github.com:nsokolis/hds5210-2021.git
#    6ee7de5..d20534e  main -> main

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 10 review exercises_ or _Everything is up to date_, then your work was submitted correctly.
